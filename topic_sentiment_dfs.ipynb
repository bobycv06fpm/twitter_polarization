# %%
import pandas as pd

# %%
#                                                   ------- Phase 1 -------
df = pd.read_pickle("topic_sentiment_pickles/phase1_repliedto")
pos0_repliedto= pd.DataFrame()
neu0_repliedto= pd.DataFrame()
neg0_repliedto= pd.DataFrame()
pos1_repliedto= pd.DataFrame()
neu1_repliedto= pd.DataFrame()
neg1_repliedto= pd.DataFrame()
pos2_repliedto= pd.DataFrame()
neu2_repliedto= pd.DataFrame()
neg2_repliedto= pd.DataFrame()
pos3_repliedto= pd.DataFrame()
neu3_repliedto= pd.DataFrame()
neg3_repliedto= pd.DataFrame()
pos4_repliedto= pd.DataFrame()
neu4_repliedto= pd.DataFrame()
neg4_repliedto= pd.DataFrame()
pos5_repliedto= pd.DataFrame()
neu5_repliedto= pd.DataFrame()
neg5_repliedto= pd.DataFrame()
pos6_repliedto= pd.DataFrame()
neu6_repliedto= pd.DataFrame()
neg6_repliedto= pd.DataFrame()
pos7_repliedto= pd.DataFrame()
neu7_repliedto= pd.DataFrame()
neg7_repliedto= pd.DataFrame()
pos8_repliedto= pd.DataFrame()
neu8_repliedto= pd.DataFrame()
neg8_repliedto= pd.DataFrame()
pos9_repliedto= pd.DataFrame()
neu9_repliedto= pd.DataFrame()
neg9_repliedto= pd.DataFrame()
df["type"] = "repliedto"
for index,row in df.head(len(df)).iterrows():
    if((row["Dominant_Topic"][0] == "0" or row["Dominant_Topic"][1] == "0") and row["Sentiment"] == "neutral"):
        neu0_repliedto = neu0_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "0" or row["Dominant_Topic"][1] == "0") and row["Sentiment"] == "positive"):
        pos0_repliedto = pos0_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "0" or row["Dominant_Topic"][1] == "0") and row["Sentiment"] == "negative"):
        neg0_repliedto = neg0_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "1" or row["Dominant_Topic"][1] == "1") and row["Sentiment"] == "neutral"):
        neu1_repliedto = neu1_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "1" or row["Dominant_Topic"][1] == "1") and row["Sentiment"] == "positive"):
        pos1_repliedto = pos1_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "1" or row["Dominant_Topic"][1] == "1") and row["Sentiment"] == "negative"):
        neg1_repliedto = neg1_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "2" or row["Dominant_Topic"][1] == "2") and row["Sentiment"] == "neutral"):
        neu2_repliedto = neu2_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "2" or row["Dominant_Topic"][1] == "2") and row["Sentiment"] == "positive"):
        pos2_repliedto = pos2_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "2" or row["Dominant_Topic"][1] == "2") and row["Sentiment"] == "negative"):
        neg2_repliedto = neg2_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "3" or row["Dominant_Topic"][1] == "3") and row["Sentiment"] == "neutral"):
        neu3_repliedto = neu3_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "3" or row["Dominant_Topic"][1] == "3") and row["Sentiment"] == "positive"):
        pos3_repliedto = pos3_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "3" or row["Dominant_Topic"][1] == "3") and row["Sentiment"] == "negative"):
        neg3_repliedto = neg3_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "4" or row["Dominant_Topic"][1] == "4") and row["Sentiment"] == "neutral"):
        neu4_repliedto = neu4_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "4" or row["Dominant_Topic"][1] == "4") and row["Sentiment"] == "positive"):
        pos4_repliedto = pos4_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "4" or row["Dominant_Topic"][1] == "4") and row["Sentiment"] == "negative"):
        neg4_repliedto = neg4_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "5" or row["Dominant_Topic"][1] == "5") and row["Sentiment"] == "neutral"):
        neu5_repliedto = neu5_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "5" or row["Dominant_Topic"][1] == "5") and row["Sentiment"] == "positive"):
        pos5_repliedto = pos5_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "5" or row["Dominant_Topic"][1] == "5") and row["Sentiment"] == "negative"):
        neg5_repliedto = neg5_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "6" or row["Dominant_Topic"][1] == "6") and row["Sentiment"] == "neutral"):
        neu6_repliedto = neu6_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "6" or row["Dominant_Topic"][1] == "6") and row["Sentiment"] == "positive"):
        pos6_repliedto = pos6_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "6" or row["Dominant_Topic"][1] == "6") and row["Sentiment"] == "negative"):
        neg6_repliedto = neg6_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "7" or row["Dominant_Topic"][1] == "7") and row["Sentiment"] == "neutral"):
        neu7_repliedto = neu7_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "7" or row["Dominant_Topic"][1] == "7") and row["Sentiment"] == "positive"):
        pos7_repliedto = pos7_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "7" or row["Dominant_Topic"][1] == "7") and row["Sentiment"] == "negative"):
        neg7_repliedto = neg7_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "8" or row["Dominant_Topic"][1] == "8") and row["Sentiment"] == "neutral"):
        neu8_repliedto = neu8_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "8" or row["Dominant_Topic"][1] == "8") and row["Sentiment"] == "positive"):
        pos8_repliedto = pos8_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "8" or row["Dominant_Topic"][1] == "8") and row["Sentiment"] == "negative"):
        neg8_repliedto = neg8_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "9" or row["Dominant_Topic"][1] == "9") and row["Sentiment"] == "neutral"):
        neu9_repliedto = neu9_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "9" or row["Dominant_Topic"][1] == "9") and row["Sentiment"] == "positive"):
        pos9_repliedto = pos9_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "9" or row["Dominant_Topic"][1] == "9") and row["Sentiment"] == "negative"):
        neg9_repliedto = neg9_repliedto.append(row)
df = pd.read_pickle("topic_sentiment_pickles/phase1_replies")
df["type"] = "reply"
for index,row in df.head(len(df)).iterrows():
    if((row["Dominant_Topic"][0] == "0" or row["Dominant_Topic"][1] == "0") and row["Sentiment"] == "neutral"):
        neu0_repliedto = neu0_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "0" or row["Dominant_Topic"][1] == "0") and row["Sentiment"] == "positive"):
        pos0_repliedto = pos0_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "0" or row["Dominant_Topic"][1] == "0") and row["Sentiment"] == "negative"):
        neg0_repliedto = neg0_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "1" or row["Dominant_Topic"][1] == "1") and row["Sentiment"] == "neutral"):
        neu1_repliedto = neu1_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "1" or row["Dominant_Topic"][1] == "1") and row["Sentiment"] == "positive"):
        pos1_repliedto = pos1_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "1" or row["Dominant_Topic"][1] == "1") and row["Sentiment"] == "negative"):
        neg1_repliedto = neg1_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "2" or row["Dominant_Topic"][1] == "2") and row["Sentiment"] == "neutral"):
        neu2_repliedto = neu2_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "2" or row["Dominant_Topic"][1] == "2") and row["Sentiment"] == "positive"):
        pos2_repliedto = pos2_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "2" or row["Dominant_Topic"][1] == "2") and row["Sentiment"] == "negative"):
        neg2_repliedto = neg2_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "3" or row["Dominant_Topic"][1] == "3") and row["Sentiment"] == "neutral"):
        neu3_repliedto = neu3_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "3" or row["Dominant_Topic"][1] == "3") and row["Sentiment"] == "positive"):
        pos3_repliedto = pos3_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "3" or row["Dominant_Topic"][1] == "3") and row["Sentiment"] == "negative"):
        neg3_repliedto = neg3_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "4" or row["Dominant_Topic"][1] == "4") and row["Sentiment"] == "neutral"):
        neu4_repliedto = neu4_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "4" or row["Dominant_Topic"][1] == "4") and row["Sentiment"] == "positive"):
        pos4_repliedto = pos4_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "4" or row["Dominant_Topic"][1] == "4") and row["Sentiment"] == "negative"):
        neg4_repliedto = neg4_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "5" or row["Dominant_Topic"][1] == "5") and row["Sentiment"] == "neutral"):
        neu5_repliedto = neu5_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "5" or row["Dominant_Topic"][1] == "5") and row["Sentiment"] == "positive"):
        pos5_repliedto = pos5_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "5" or row["Dominant_Topic"][1] == "5") and row["Sentiment"] == "negative"):
        neg5_repliedto = neg5_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "6" or row["Dominant_Topic"][1] == "6") and row["Sentiment"] == "neutral"):
        neu6_repliedto = neu6_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "6" or row["Dominant_Topic"][1] == "6") and row["Sentiment"] == "positive"):
        pos6_repliedto = pos6_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "6" or row["Dominant_Topic"][1] == "6") and row["Sentiment"] == "negative"):
        neg6_repliedto = neg6_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "7" or row["Dominant_Topic"][1] == "7") and row["Sentiment"] == "neutral"):
        neu7_repliedto = neu7_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "7" or row["Dominant_Topic"][1] == "7") and row["Sentiment"] == "positive"):
        pos7_repliedto = pos7_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "7" or row["Dominant_Topic"][1] == "7") and row["Sentiment"] == "negative"):
        neg7_repliedto = neg7_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "8" or row["Dominant_Topic"][1] == "8") and row["Sentiment"] == "neutral"):
        neu8_repliedto = neu8_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "8" or row["Dominant_Topic"][1] == "8") and row["Sentiment"] == "positive"):
        pos8_repliedto = pos8_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "8" or row["Dominant_Topic"][1] == "8") and row["Sentiment"] == "negative"):
        neg8_repliedto = neg8_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "9" or row["Dominant_Topic"][1] == "9") and row["Sentiment"] == "neutral"):
        neu9_repliedto = neu9_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "9" or row["Dominant_Topic"][1] == "9") and row["Sentiment"] == "positive"):
        pos9_repliedto = pos9_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "9" or row["Dominant_Topic"][1] == "9") and row["Sentiment"] == "negative"):
        neg9_repliedto = neg9_repliedto.append(row)
df = pd.read_pickle("topic_sentiment_pickles/phase1_tweets")
df["type"] = "tweet"
for index,row in df.head(len(df)).iterrows():
    if((row["Dominant_Topic"][0] == "0" or row["Dominant_Topic"][1] == "0") and row["Sentiment"] == "neutral"):
        neu0_repliedto = neu0_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "0" or row["Dominant_Topic"][1] == "0") and row["Sentiment"] == "positive"):
        pos0_repliedto = pos0_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "0" or row["Dominant_Topic"][1] == "0") and row["Sentiment"] == "negative"):
        neg0_repliedto = neg0_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "1" or row["Dominant_Topic"][1] == "1") and row["Sentiment"] == "neutral"):
        neu1_repliedto = neu1_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "1" or row["Dominant_Topic"][1] == "1") and row["Sentiment"] == "positive"):
        pos1_repliedto = pos1_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "1" or row["Dominant_Topic"][1] == "1") and row["Sentiment"] == "negative"):
        neg1_repliedto = neg1_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "2" or row["Dominant_Topic"][1] == "2") and row["Sentiment"] == "neutral"):
        neu2_repliedto = neu2_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "2" or row["Dominant_Topic"][1] == "2") and row["Sentiment"] == "positive"):
        pos2_repliedto = pos2_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "2" or row["Dominant_Topic"][1] == "2") and row["Sentiment"] == "negative"):
        neg2_repliedto = neg2_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "3" or row["Dominant_Topic"][1] == "3") and row["Sentiment"] == "neutral"):
        neu3_repliedto = neu3_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "3" or row["Dominant_Topic"][1] == "3") and row["Sentiment"] == "positive"):
        pos3_repliedto = pos3_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "3" or row["Dominant_Topic"][1] == "3") and row["Sentiment"] == "negative"):
        neg3_repliedto = neg3_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "4" or row["Dominant_Topic"][1] == "4") and row["Sentiment"] == "neutral"):
        neu4_repliedto = neu4_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "4" or row["Dominant_Topic"][1] == "4") and row["Sentiment"] == "positive"):
        pos4_repliedto = pos4_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "4" or row["Dominant_Topic"][1] == "4") and row["Sentiment"] == "negative"):
        neg4_repliedto = neg4_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "5" or row["Dominant_Topic"][1] == "5") and row["Sentiment"] == "neutral"):
        neu5_repliedto = neu5_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "5" or row["Dominant_Topic"][1] == "5") and row["Sentiment"] == "positive"):
        pos5_repliedto = pos5_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "5" or row["Dominant_Topic"][1] == "5") and row["Sentiment"] == "negative"):
        neg5_repliedto = neg5_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "6" or row["Dominant_Topic"][1] == "6") and row["Sentiment"] == "neutral"):
        neu6_repliedto = neu6_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "6" or row["Dominant_Topic"][1] == "6") and row["Sentiment"] == "positive"):
        pos6_repliedto = pos6_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "6" or row["Dominant_Topic"][1] == "6") and row["Sentiment"] == "negative"):
        neg6_repliedto = neg6_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "7" or row["Dominant_Topic"][1] == "7") and row["Sentiment"] == "neutral"):
        neu7_repliedto = neu7_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "7" or row["Dominant_Topic"][1] == "7") and row["Sentiment"] == "positive"):
        pos7_repliedto = pos7_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "7" or row["Dominant_Topic"][1] == "7") and row["Sentiment"] == "negative"):
        neg7_repliedto = neg7_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "8" or row["Dominant_Topic"][1] == "8") and row["Sentiment"] == "neutral"):
        neu8_repliedto = neu8_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "8" or row["Dominant_Topic"][1] == "8") and row["Sentiment"] == "positive"):
        pos8_repliedto = pos8_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "8" or row["Dominant_Topic"][1] == "8") and row["Sentiment"] == "negative"):
        neg8_repliedto = neg8_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "9" or row["Dominant_Topic"][1] == "9") and row["Sentiment"] == "neutral"):
        neu9_repliedto = neu9_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "9" or row["Dominant_Topic"][1] == "9") and row["Sentiment"] == "positive"):
        pos9_repliedto = pos9_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "9" or row["Dominant_Topic"][1] == "9") and row["Sentiment"] == "negative"):
        neg9_repliedto = neg9_repliedto.append(row)

pos0_repliedto.to_pickle("topic_sentiment_dfs/pos0_phase1")
neu0_repliedto.to_pickle("topic_sentiment_dfs/neu0_phase1")
neg0_repliedto.to_pickle("topic_sentiment_dfs/neg0_phase1")
pos1_repliedto.to_pickle("topic_sentiment_dfs/pos1_phase1")
neu1_repliedto.to_pickle("topic_sentiment_dfs/neu1_phase1")
neg1_repliedto.to_pickle("topic_sentiment_dfs/neg1_phase1")
pos2_repliedto.to_pickle("topic_sentiment_dfs/pos2_phase1")
neu2_repliedto.to_pickle("topic_sentiment_dfs/neu2_phase1")
neg2_repliedto.to_pickle("topic_sentiment_dfs/neg2_phase1")
pos3_repliedto.to_pickle("topic_sentiment_dfs/pos3_phase1")
neu3_repliedto.to_pickle("topic_sentiment_dfs/neu3_phase1")
neg3_repliedto.to_pickle("topic_sentiment_dfs/neg3_phase1")
pos4_repliedto.to_pickle("topic_sentiment_dfs/pos4_phase1")
neu4_repliedto.to_pickle("topic_sentiment_dfs/neu4_phase1")
neg4_repliedto.to_pickle("topic_sentiment_dfs/neg4_phase1")
pos5_repliedto.to_pickle("topic_sentiment_dfs/pos5_phase1")
neu5_repliedto.to_pickle("topic_sentiment_dfs/neu5_phase1")
neg5_repliedto.to_pickle("topic_sentiment_dfs/neg5_phase1")
pos6_repliedto.to_pickle("topic_sentiment_dfs/pos6_phase1")
neu6_repliedto.to_pickle("topic_sentiment_dfs/neu6_phase1")
neg6_repliedto.to_pickle("topic_sentiment_dfs/neg6_phase1")
pos7_repliedto.to_pickle("topic_sentiment_dfs/pos7_phase1")
neu7_repliedto.to_pickle("topic_sentiment_dfs/neu7_phase1")
neg7_repliedto.to_pickle("topic_sentiment_dfs/neg7_phase1")
pos8_repliedto.to_pickle("topic_sentiment_dfs/pos8_phase1")
neu8_repliedto.to_pickle("topic_sentiment_dfs/neu8_phase1")
neg8_repliedto.to_pickle("topic_sentiment_dfs/neg8_phase1")
pos9_repliedto.to_pickle("topic_sentiment_dfs/pos9_phase1")
neu9_repliedto.to_pickle("topic_sentiment_dfs/neu9_phase1")
neg9_repliedto.to_pickle("topic_sentiment_dfs/neg9_phase1")

# %%
#                                                   ------- Phase 2 -------
df = pd.read_pickle("topic_sentiment_pickles/phase2_repliedto")
pos0_repliedto= pd.DataFrame()
neu0_repliedto= pd.DataFrame()
neg0_repliedto= pd.DataFrame()
pos1_repliedto= pd.DataFrame()
neu1_repliedto= pd.DataFrame()
neg1_repliedto= pd.DataFrame()
pos2_repliedto= pd.DataFrame()
neu2_repliedto= pd.DataFrame()
neg2_repliedto= pd.DataFrame()
pos3_repliedto= pd.DataFrame()
neu3_repliedto= pd.DataFrame()
neg3_repliedto= pd.DataFrame()
pos4_repliedto= pd.DataFrame()
neu4_repliedto= pd.DataFrame()
neg4_repliedto= pd.DataFrame()
pos5_repliedto= pd.DataFrame()
neu5_repliedto= pd.DataFrame()
neg5_repliedto= pd.DataFrame()
pos6_repliedto= pd.DataFrame()
neu6_repliedto= pd.DataFrame()
neg6_repliedto= pd.DataFrame()
pos7_repliedto= pd.DataFrame()
neu7_repliedto= pd.DataFrame()
neg7_repliedto= pd.DataFrame()
pos8_repliedto= pd.DataFrame()
neu8_repliedto= pd.DataFrame()
neg8_repliedto= pd.DataFrame()
pos9_repliedto= pd.DataFrame()
neu9_repliedto= pd.DataFrame()
neg9_repliedto= pd.DataFrame()
df["type"] = "repliedto"
for index,row in df.head(len(df)).iterrows():
    if((row["Dominant_Topic"][0] == "0" or row["Dominant_Topic"][1] == "0") and row["Sentiment"] == "neutral"):
        neu0_repliedto = neu0_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "0" or row["Dominant_Topic"][1] == "0") and row["Sentiment"] == "positive"):
        pos0_repliedto = pos0_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "0" or row["Dominant_Topic"][1] == "0") and row["Sentiment"] == "negative"):
        neg0_repliedto = neg0_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "1" or row["Dominant_Topic"][1] == "1") and row["Sentiment"] == "neutral"):
        neu1_repliedto = neu1_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "1" or row["Dominant_Topic"][1] == "1") and row["Sentiment"] == "positive"):
        pos1_repliedto = pos1_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "1" or row["Dominant_Topic"][1] == "1") and row["Sentiment"] == "negative"):
        neg1_repliedto = neg1_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "2" or row["Dominant_Topic"][1] == "2") and row["Sentiment"] == "neutral"):
        neu2_repliedto = neu2_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "2" or row["Dominant_Topic"][1] == "2") and row["Sentiment"] == "positive"):
        pos2_repliedto = pos2_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "2" or row["Dominant_Topic"][1] == "2") and row["Sentiment"] == "negative"):
        neg2_repliedto = neg2_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "3" or row["Dominant_Topic"][1] == "3") and row["Sentiment"] == "neutral"):
        neu3_repliedto = neu3_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "3" or row["Dominant_Topic"][1] == "3") and row["Sentiment"] == "positive"):
        pos3_repliedto = pos3_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "3" or row["Dominant_Topic"][1] == "3") and row["Sentiment"] == "negative"):
        neg3_repliedto = neg3_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "4" or row["Dominant_Topic"][1] == "4") and row["Sentiment"] == "neutral"):
        neu4_repliedto = neu4_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "4" or row["Dominant_Topic"][1] == "4") and row["Sentiment"] == "positive"):
        pos4_repliedto = pos4_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "4" or row["Dominant_Topic"][1] == "4") and row["Sentiment"] == "negative"):
        neg4_repliedto = neg4_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "5" or row["Dominant_Topic"][1] == "5") and row["Sentiment"] == "neutral"):
        neu5_repliedto = neu5_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "5" or row["Dominant_Topic"][1] == "5") and row["Sentiment"] == "positive"):
        pos5_repliedto = pos5_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "5" or row["Dominant_Topic"][1] == "5") and row["Sentiment"] == "negative"):
        neg5_repliedto = neg5_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "6" or row["Dominant_Topic"][1] == "6") and row["Sentiment"] == "neutral"):
        neu6_repliedto = neu6_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "6" or row["Dominant_Topic"][1] == "6") and row["Sentiment"] == "positive"):
        pos6_repliedto = pos6_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "6" or row["Dominant_Topic"][1] == "6") and row["Sentiment"] == "negative"):
        neg6_repliedto = neg6_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "7" or row["Dominant_Topic"][1] == "7") and row["Sentiment"] == "neutral"):
        neu7_repliedto = neu7_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "7" or row["Dominant_Topic"][1] == "7") and row["Sentiment"] == "positive"):
        pos7_repliedto = pos7_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "7" or row["Dominant_Topic"][1] == "7") and row["Sentiment"] == "negative"):
        neg7_repliedto = neg7_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "8" or row["Dominant_Topic"][1] == "8") and row["Sentiment"] == "neutral"):
        neu8_repliedto = neu8_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "8" or row["Dominant_Topic"][1] == "8") and row["Sentiment"] == "positive"):
        pos8_repliedto = pos8_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "8" or row["Dominant_Topic"][1] == "8") and row["Sentiment"] == "negative"):
        neg8_repliedto = neg8_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "9" or row["Dominant_Topic"][1] == "9") and row["Sentiment"] == "neutral"):
        neu9_repliedto = neu9_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "9" or row["Dominant_Topic"][1] == "9") and row["Sentiment"] == "positive"):
        pos9_repliedto = pos9_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "9" or row["Dominant_Topic"][1] == "9") and row["Sentiment"] == "negative"):
        neg9_repliedto = neg9_repliedto.append(row)
df = pd.read_pickle("topic_sentiment_pickles/phase2_replies")
df["type"] = "reply"
for index,row in df.head(len(df)).iterrows():
    if((row["Dominant_Topic"][0] == "0" or row["Dominant_Topic"][1] == "0") and row["Sentiment"] == "neutral"):
        neu0_repliedto = neu0_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "0" or row["Dominant_Topic"][1] == "0") and row["Sentiment"] == "positive"):
        pos0_repliedto = pos0_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "0" or row["Dominant_Topic"][1] == "0") and row["Sentiment"] == "negative"):
        neg0_repliedto = neg0_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "1" or row["Dominant_Topic"][1] == "1") and row["Sentiment"] == "neutral"):
        neu1_repliedto = neu1_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "1" or row["Dominant_Topic"][1] == "1") and row["Sentiment"] == "positive"):
        pos1_repliedto = pos1_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "1" or row["Dominant_Topic"][1] == "1") and row["Sentiment"] == "negative"):
        neg1_repliedto = neg1_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "2" or row["Dominant_Topic"][1] == "2") and row["Sentiment"] == "neutral"):
        neu2_repliedto = neu2_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "2" or row["Dominant_Topic"][1] == "2") and row["Sentiment"] == "positive"):
        pos2_repliedto = pos2_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "2" or row["Dominant_Topic"][1] == "2") and row["Sentiment"] == "negative"):
        neg2_repliedto = neg2_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "3" or row["Dominant_Topic"][1] == "3") and row["Sentiment"] == "neutral"):
        neu3_repliedto = neu3_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "3" or row["Dominant_Topic"][1] == "3") and row["Sentiment"] == "positive"):
        pos3_repliedto = pos3_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "3" or row["Dominant_Topic"][1] == "3") and row["Sentiment"] == "negative"):
        neg3_repliedto = neg3_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "4" or row["Dominant_Topic"][1] == "4") and row["Sentiment"] == "neutral"):
        neu4_repliedto = neu4_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "4" or row["Dominant_Topic"][1] == "4") and row["Sentiment"] == "positive"):
        pos4_repliedto = pos4_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "4" or row["Dominant_Topic"][1] == "4") and row["Sentiment"] == "negative"):
        neg4_repliedto = neg4_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "5" or row["Dominant_Topic"][1] == "5") and row["Sentiment"] == "neutral"):
        neu5_repliedto = neu5_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "5" or row["Dominant_Topic"][1] == "5") and row["Sentiment"] == "positive"):
        pos5_repliedto = pos5_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "5" or row["Dominant_Topic"][1] == "5") and row["Sentiment"] == "negative"):
        neg5_repliedto = neg5_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "6" or row["Dominant_Topic"][1] == "6") and row["Sentiment"] == "neutral"):
        neu6_repliedto = neu6_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "6" or row["Dominant_Topic"][1] == "6") and row["Sentiment"] == "positive"):
        pos6_repliedto = pos6_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "6" or row["Dominant_Topic"][1] == "6") and row["Sentiment"] == "negative"):
        neg6_repliedto = neg6_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "7" or row["Dominant_Topic"][1] == "7") and row["Sentiment"] == "neutral"):
        neu7_repliedto = neu7_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "7" or row["Dominant_Topic"][1] == "7") and row["Sentiment"] == "positive"):
        pos7_repliedto = pos7_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "7" or row["Dominant_Topic"][1] == "7") and row["Sentiment"] == "negative"):
        neg7_repliedto = neg7_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "8" or row["Dominant_Topic"][1] == "8") and row["Sentiment"] == "neutral"):
        neu8_repliedto = neu8_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "8" or row["Dominant_Topic"][1] == "8") and row["Sentiment"] == "positive"):
        pos8_repliedto = pos8_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "8" or row["Dominant_Topic"][1] == "8") and row["Sentiment"] == "negative"):
        neg8_repliedto = neg8_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "9" or row["Dominant_Topic"][1] == "9") and row["Sentiment"] == "neutral"):
        neu9_repliedto = neu9_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "9" or row["Dominant_Topic"][1] == "9") and row["Sentiment"] == "positive"):
        pos9_repliedto = pos9_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "9" or row["Dominant_Topic"][1] == "9") and row["Sentiment"] == "negative"):
        neg9_repliedto = neg9_repliedto.append(row)
df = pd.read_pickle("topic_sentiment_pickles/phase2_tweets")
df["type"] = "tweet"
for index,row in df.head(len(df)).iterrows():
    if((row["Dominant_Topic"][0] == "0" or row["Dominant_Topic"][1] == "0") and row["Sentiment"] == "neutral"):
        neu0_repliedto = neu0_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "0" or row["Dominant_Topic"][1] == "0") and row["Sentiment"] == "positive"):
        pos0_repliedto = pos0_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "0" or row["Dominant_Topic"][1] == "0") and row["Sentiment"] == "negative"):
        neg0_repliedto = neg0_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "1" or row["Dominant_Topic"][1] == "1") and row["Sentiment"] == "neutral"):
        neu1_repliedto = neu1_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "1" or row["Dominant_Topic"][1] == "1") and row["Sentiment"] == "positive"):
        pos1_repliedto = pos1_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "1" or row["Dominant_Topic"][1] == "1") and row["Sentiment"] == "negative"):
        neg1_repliedto = neg1_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "2" or row["Dominant_Topic"][1] == "2") and row["Sentiment"] == "neutral"):
        neu2_repliedto = neu2_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "2" or row["Dominant_Topic"][1] == "2") and row["Sentiment"] == "positive"):
        pos2_repliedto = pos2_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "2" or row["Dominant_Topic"][1] == "2") and row["Sentiment"] == "negative"):
        neg2_repliedto = neg2_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "3" or row["Dominant_Topic"][1] == "3") and row["Sentiment"] == "neutral"):
        neu3_repliedto = neu3_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "3" or row["Dominant_Topic"][1] == "3") and row["Sentiment"] == "positive"):
        pos3_repliedto = pos3_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "3" or row["Dominant_Topic"][1] == "3") and row["Sentiment"] == "negative"):
        neg3_repliedto = neg3_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "4" or row["Dominant_Topic"][1] == "4") and row["Sentiment"] == "neutral"):
        neu4_repliedto = neu4_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "4" or row["Dominant_Topic"][1] == "4") and row["Sentiment"] == "positive"):
        pos4_repliedto = pos4_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "4" or row["Dominant_Topic"][1] == "4") and row["Sentiment"] == "negative"):
        neg4_repliedto = neg4_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "5" or row["Dominant_Topic"][1] == "5") and row["Sentiment"] == "neutral"):
        neu5_repliedto = neu5_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "5" or row["Dominant_Topic"][1] == "5") and row["Sentiment"] == "positive"):
        pos5_repliedto = pos5_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "5" or row["Dominant_Topic"][1] == "5") and row["Sentiment"] == "negative"):
        neg5_repliedto = neg5_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "6" or row["Dominant_Topic"][1] == "6") and row["Sentiment"] == "neutral"):
        neu6_repliedto = neu6_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "6" or row["Dominant_Topic"][1] == "6") and row["Sentiment"] == "positive"):
        pos6_repliedto = pos6_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "6" or row["Dominant_Topic"][1] == "6") and row["Sentiment"] == "negative"):
        neg6_repliedto = neg6_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "7" or row["Dominant_Topic"][1] == "7") and row["Sentiment"] == "neutral"):
        neu7_repliedto = neu7_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "7" or row["Dominant_Topic"][1] == "7") and row["Sentiment"] == "positive"):
        pos7_repliedto = pos7_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "7" or row["Dominant_Topic"][1] == "7") and row["Sentiment"] == "negative"):
        neg7_repliedto = neg7_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "8" or row["Dominant_Topic"][1] == "8") and row["Sentiment"] == "neutral"):
        neu8_repliedto = neu8_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "8" or row["Dominant_Topic"][1] == "8") and row["Sentiment"] == "positive"):
        pos8_repliedto = pos8_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "8" or row["Dominant_Topic"][1] == "8") and row["Sentiment"] == "negative"):
        neg8_repliedto = neg8_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "9" or row["Dominant_Topic"][1] == "9") and row["Sentiment"] == "neutral"):
        neu9_repliedto = neu9_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "9" or row["Dominant_Topic"][1] == "9") and row["Sentiment"] == "positive"):
        pos9_repliedto = pos9_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "9" or row["Dominant_Topic"][1] == "9") and row["Sentiment"] == "negative"):
        neg9_repliedto = neg9_repliedto.append(row)

pos0_repliedto.to_pickle("topic_sentiment_dfs/pos0_phase2")
neu0_repliedto.to_pickle("topic_sentiment_dfs/neu0_phase2")
neg0_repliedto.to_pickle("topic_sentiment_dfs/neg0_phase2")
pos1_repliedto.to_pickle("topic_sentiment_dfs/pos1_phase2")
neu1_repliedto.to_pickle("topic_sentiment_dfs/neu1_phase2")
neg1_repliedto.to_pickle("topic_sentiment_dfs/neg1_phase2")
pos2_repliedto.to_pickle("topic_sentiment_dfs/pos2_phase2")
neu2_repliedto.to_pickle("topic_sentiment_dfs/neu2_phase2")
neg2_repliedto.to_pickle("topic_sentiment_dfs/neg2_phase2")
pos3_repliedto.to_pickle("topic_sentiment_dfs/pos3_phase2")
neu3_repliedto.to_pickle("topic_sentiment_dfs/neu3_phase2")
neg3_repliedto.to_pickle("topic_sentiment_dfs/neg3_phase2")
pos4_repliedto.to_pickle("topic_sentiment_dfs/pos4_phase2")
neu4_repliedto.to_pickle("topic_sentiment_dfs/neu4_phase2")
neg4_repliedto.to_pickle("topic_sentiment_dfs/neg4_phase2")
pos5_repliedto.to_pickle("topic_sentiment_dfs/pos5_phase2")
neu5_repliedto.to_pickle("topic_sentiment_dfs/neu5_phase2")
neg5_repliedto.to_pickle("topic_sentiment_dfs/neg5_phase2")
pos6_repliedto.to_pickle("topic_sentiment_dfs/pos6_phase2")
neu6_repliedto.to_pickle("topic_sentiment_dfs/neu6_phase2")
neg6_repliedto.to_pickle("topic_sentiment_dfs/neg6_phase2")
pos7_repliedto.to_pickle("topic_sentiment_dfs/pos7_phase2")
neu7_repliedto.to_pickle("topic_sentiment_dfs/neu7_phase2")
neg7_repliedto.to_pickle("topic_sentiment_dfs/neg7_phase2")
pos8_repliedto.to_pickle("topic_sentiment_dfs/pos8_phase2")
neu8_repliedto.to_pickle("topic_sentiment_dfs/neu8_phase2")
neg8_repliedto.to_pickle("topic_sentiment_dfs/neg8_phase2")
pos9_repliedto.to_pickle("topic_sentiment_dfs/pos9_phase2")
neu9_repliedto.to_pickle("topic_sentiment_dfs/neu9_phase2")
neg9_repliedto.to_pickle("topic_sentiment_dfs/neg9_phase2")

# %%
#                                                   ------- Phase 3 -------
df = pd.read_pickle("topic_sentiment_pickles/phase3_repliedto")
pos0_repliedto= pd.DataFrame()
neu0_repliedto= pd.DataFrame()
neg0_repliedto= pd.DataFrame()
pos1_repliedto= pd.DataFrame()
neu1_repliedto= pd.DataFrame()
neg1_repliedto= pd.DataFrame()
pos2_repliedto= pd.DataFrame()
neu2_repliedto= pd.DataFrame()
neg2_repliedto= pd.DataFrame()
pos3_repliedto= pd.DataFrame()
neu3_repliedto= pd.DataFrame()
neg3_repliedto= pd.DataFrame()
pos4_repliedto= pd.DataFrame()
neu4_repliedto= pd.DataFrame()
neg4_repliedto= pd.DataFrame()
pos5_repliedto= pd.DataFrame()
neu5_repliedto= pd.DataFrame()
neg5_repliedto= pd.DataFrame()
pos6_repliedto= pd.DataFrame()
neu6_repliedto= pd.DataFrame()
neg6_repliedto= pd.DataFrame()
pos7_repliedto= pd.DataFrame()
neu7_repliedto= pd.DataFrame()
neg7_repliedto= pd.DataFrame()
pos8_repliedto= pd.DataFrame()
neu8_repliedto= pd.DataFrame()
neg8_repliedto= pd.DataFrame()
pos9_repliedto= pd.DataFrame()
neu9_repliedto= pd.DataFrame()
neg9_repliedto= pd.DataFrame()
df["type"] = "repliedto"
for index,row in df.head(len(df)).iterrows():
    if((row["Dominant_Topic"][0] == "0" or row["Dominant_Topic"][1] == "0") and row["Sentiment"] == "neutral"):
        neu0_repliedto = neu0_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "0" or row["Dominant_Topic"][1] == "0") and row["Sentiment"] == "positive"):
        pos0_repliedto = pos0_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "0" or row["Dominant_Topic"][1] == "0") and row["Sentiment"] == "negative"):
        neg0_repliedto = neg0_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "1" or row["Dominant_Topic"][1] == "1") and row["Sentiment"] == "neutral"):
        neu1_repliedto = neu1_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "1" or row["Dominant_Topic"][1] == "1") and row["Sentiment"] == "positive"):
        pos1_repliedto = pos1_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "1" or row["Dominant_Topic"][1] == "1") and row["Sentiment"] == "negative"):
        neg1_repliedto = neg1_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "2" or row["Dominant_Topic"][1] == "2") and row["Sentiment"] == "neutral"):
        neu2_repliedto = neu2_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "2" or row["Dominant_Topic"][1] == "2") and row["Sentiment"] == "positive"):
        pos2_repliedto = pos2_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "2" or row["Dominant_Topic"][1] == "2") and row["Sentiment"] == "negative"):
        neg2_repliedto = neg2_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "3" or row["Dominant_Topic"][1] == "3") and row["Sentiment"] == "neutral"):
        neu3_repliedto = neu3_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "3" or row["Dominant_Topic"][1] == "3") and row["Sentiment"] == "positive"):
        pos3_repliedto = pos3_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "3" or row["Dominant_Topic"][1] == "3") and row["Sentiment"] == "negative"):
        neg3_repliedto = neg3_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "4" or row["Dominant_Topic"][1] == "4") and row["Sentiment"] == "neutral"):
        neu4_repliedto = neu4_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "4" or row["Dominant_Topic"][1] == "4") and row["Sentiment"] == "positive"):
        pos4_repliedto = pos4_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "4" or row["Dominant_Topic"][1] == "4") and row["Sentiment"] == "negative"):
        neg4_repliedto = neg4_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "5" or row["Dominant_Topic"][1] == "5") and row["Sentiment"] == "neutral"):
        neu5_repliedto = neu5_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "5" or row["Dominant_Topic"][1] == "5") and row["Sentiment"] == "positive"):
        pos5_repliedto = pos5_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "5" or row["Dominant_Topic"][1] == "5") and row["Sentiment"] == "negative"):
        neg5_repliedto = neg5_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "6" or row["Dominant_Topic"][1] == "6") and row["Sentiment"] == "neutral"):
        neu6_repliedto = neu6_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "6" or row["Dominant_Topic"][1] == "6") and row["Sentiment"] == "positive"):
        pos6_repliedto = pos6_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "6" or row["Dominant_Topic"][1] == "6") and row["Sentiment"] == "negative"):
        neg6_repliedto = neg6_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "7" or row["Dominant_Topic"][1] == "7") and row["Sentiment"] == "neutral"):
        neu7_repliedto = neu7_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "7" or row["Dominant_Topic"][1] == "7") and row["Sentiment"] == "positive"):
        pos7_repliedto = pos7_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "7" or row["Dominant_Topic"][1] == "7") and row["Sentiment"] == "negative"):
        neg7_repliedto = neg7_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "8" or row["Dominant_Topic"][1] == "8") and row["Sentiment"] == "neutral"):
        neu8_repliedto = neu8_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "8" or row["Dominant_Topic"][1] == "8") and row["Sentiment"] == "positive"):
        pos8_repliedto = pos8_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "8" or row["Dominant_Topic"][1] == "8") and row["Sentiment"] == "negative"):
        neg8_repliedto = neg8_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "9" or row["Dominant_Topic"][1] == "9") and row["Sentiment"] == "neutral"):
        neu9_repliedto = neu9_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "9" or row["Dominant_Topic"][1] == "9") and row["Sentiment"] == "positive"):
        pos9_repliedto = pos9_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "9" or row["Dominant_Topic"][1] == "9") and row["Sentiment"] == "negative"):
        neg9_repliedto = neg9_repliedto.append(row)
df = pd.read_pickle("topic_sentiment_pickles/phase3_replies")
df["type"] = "reply"
for index,row in df.head(len(df)).iterrows():
    if((row["Dominant_Topic"][0] == "0" or row["Dominant_Topic"][1] == "0") and row["Sentiment"] == "neutral"):
        neu0_repliedto = neu0_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "0" or row["Dominant_Topic"][1] == "0") and row["Sentiment"] == "positive"):
        pos0_repliedto = pos0_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "0" or row["Dominant_Topic"][1] == "0") and row["Sentiment"] == "negative"):
        neg0_repliedto = neg0_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "1" or row["Dominant_Topic"][1] == "1") and row["Sentiment"] == "neutral"):
        neu1_repliedto = neu1_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "1" or row["Dominant_Topic"][1] == "1") and row["Sentiment"] == "positive"):
        pos1_repliedto = pos1_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "1" or row["Dominant_Topic"][1] == "1") and row["Sentiment"] == "negative"):
        neg1_repliedto = neg1_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "2" or row["Dominant_Topic"][1] == "2") and row["Sentiment"] == "neutral"):
        neu2_repliedto = neu2_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "2" or row["Dominant_Topic"][1] == "2") and row["Sentiment"] == "positive"):
        pos2_repliedto = pos2_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "2" or row["Dominant_Topic"][1] == "2") and row["Sentiment"] == "negative"):
        neg2_repliedto = neg2_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "3" or row["Dominant_Topic"][1] == "3") and row["Sentiment"] == "neutral"):
        neu3_repliedto = neu3_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "3" or row["Dominant_Topic"][1] == "3") and row["Sentiment"] == "positive"):
        pos3_repliedto = pos3_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "3" or row["Dominant_Topic"][1] == "3") and row["Sentiment"] == "negative"):
        neg3_repliedto = neg3_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "4" or row["Dominant_Topic"][1] == "4") and row["Sentiment"] == "neutral"):
        neu4_repliedto = neu4_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "4" or row["Dominant_Topic"][1] == "4") and row["Sentiment"] == "positive"):
        pos4_repliedto = pos4_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "4" or row["Dominant_Topic"][1] == "4") and row["Sentiment"] == "negative"):
        neg4_repliedto = neg4_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "5" or row["Dominant_Topic"][1] == "5") and row["Sentiment"] == "neutral"):
        neu5_repliedto = neu5_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "5" or row["Dominant_Topic"][1] == "5") and row["Sentiment"] == "positive"):
        pos5_repliedto = pos5_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "5" or row["Dominant_Topic"][1] == "5") and row["Sentiment"] == "negative"):
        neg5_repliedto = neg5_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "6" or row["Dominant_Topic"][1] == "6") and row["Sentiment"] == "neutral"):
        neu6_repliedto = neu6_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "6" or row["Dominant_Topic"][1] == "6") and row["Sentiment"] == "positive"):
        pos6_repliedto = pos6_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "6" or row["Dominant_Topic"][1] == "6") and row["Sentiment"] == "negative"):
        neg6_repliedto = neg6_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "7" or row["Dominant_Topic"][1] == "7") and row["Sentiment"] == "neutral"):
        neu7_repliedto = neu7_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "7" or row["Dominant_Topic"][1] == "7") and row["Sentiment"] == "positive"):
        pos7_repliedto = pos7_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "7" or row["Dominant_Topic"][1] == "7") and row["Sentiment"] == "negative"):
        neg7_repliedto = neg7_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "8" or row["Dominant_Topic"][1] == "8") and row["Sentiment"] == "neutral"):
        neu8_repliedto = neu8_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "8" or row["Dominant_Topic"][1] == "8") and row["Sentiment"] == "positive"):
        pos8_repliedto = pos8_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "8" or row["Dominant_Topic"][1] == "8") and row["Sentiment"] == "negative"):
        neg8_repliedto = neg8_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "9" or row["Dominant_Topic"][1] == "9") and row["Sentiment"] == "neutral"):
        neu9_repliedto = neu9_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "9" or row["Dominant_Topic"][1] == "9") and row["Sentiment"] == "positive"):
        pos9_repliedto = pos9_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "9" or row["Dominant_Topic"][1] == "9") and row["Sentiment"] == "negative"):
        neg9_repliedto = neg9_repliedto.append(row)
df = pd.read_pickle("topic_sentiment_pickles/phase3_tweets")
df["type"] = "tweet"
for index,row in df.head(len(df)).iterrows():
    if((row["Dominant_Topic"][0] == "0" or row["Dominant_Topic"][1] == "0") and row["Sentiment"] == "neutral"):
        neu0_repliedto = neu0_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "0" or row["Dominant_Topic"][1] == "0") and row["Sentiment"] == "positive"):
        pos0_repliedto = pos0_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "0" or row["Dominant_Topic"][1] == "0") and row["Sentiment"] == "negative"):
        neg0_repliedto = neg0_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "1" or row["Dominant_Topic"][1] == "1") and row["Sentiment"] == "neutral"):
        neu1_repliedto = neu1_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "1" or row["Dominant_Topic"][1] == "1") and row["Sentiment"] == "positive"):
        pos1_repliedto = pos1_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "1" or row["Dominant_Topic"][1] == "1") and row["Sentiment"] == "negative"):
        neg1_repliedto = neg1_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "2" or row["Dominant_Topic"][1] == "2") and row["Sentiment"] == "neutral"):
        neu2_repliedto = neu2_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "2" or row["Dominant_Topic"][1] == "2") and row["Sentiment"] == "positive"):
        pos2_repliedto = pos2_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "2" or row["Dominant_Topic"][1] == "2") and row["Sentiment"] == "negative"):
        neg2_repliedto = neg2_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "3" or row["Dominant_Topic"][1] == "3") and row["Sentiment"] == "neutral"):
        neu3_repliedto = neu3_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "3" or row["Dominant_Topic"][1] == "3") and row["Sentiment"] == "positive"):
        pos3_repliedto = pos3_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "3" or row["Dominant_Topic"][1] == "3") and row["Sentiment"] == "negative"):
        neg3_repliedto = neg3_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "4" or row["Dominant_Topic"][1] == "4") and row["Sentiment"] == "neutral"):
        neu4_repliedto = neu4_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "4" or row["Dominant_Topic"][1] == "4") and row["Sentiment"] == "positive"):
        pos4_repliedto = pos4_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "4" or row["Dominant_Topic"][1] == "4") and row["Sentiment"] == "negative"):
        neg4_repliedto = neg4_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "5" or row["Dominant_Topic"][1] == "5") and row["Sentiment"] == "neutral"):
        neu5_repliedto = neu5_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "5" or row["Dominant_Topic"][1] == "5") and row["Sentiment"] == "positive"):
        pos5_repliedto = pos5_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "5" or row["Dominant_Topic"][1] == "5") and row["Sentiment"] == "negative"):
        neg5_repliedto = neg5_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "6" or row["Dominant_Topic"][1] == "6") and row["Sentiment"] == "neutral"):
        neu6_repliedto = neu6_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "6" or row["Dominant_Topic"][1] == "6") and row["Sentiment"] == "positive"):
        pos6_repliedto = pos6_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "6" or row["Dominant_Topic"][1] == "6") and row["Sentiment"] == "negative"):
        neg6_repliedto = neg6_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "7" or row["Dominant_Topic"][1] == "7") and row["Sentiment"] == "neutral"):
        neu7_repliedto = neu7_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "7" or row["Dominant_Topic"][1] == "7") and row["Sentiment"] == "positive"):
        pos7_repliedto = pos7_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "7" or row["Dominant_Topic"][1] == "7") and row["Sentiment"] == "negative"):
        neg7_repliedto = neg7_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "8" or row["Dominant_Topic"][1] == "8") and row["Sentiment"] == "neutral"):
        neu8_repliedto = neu8_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "8" or row["Dominant_Topic"][1] == "8") and row["Sentiment"] == "positive"):
        pos8_repliedto = pos8_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "8" or row["Dominant_Topic"][1] == "8") and row["Sentiment"] == "negative"):
        neg8_repliedto = neg8_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "9" or row["Dominant_Topic"][1] == "9") and row["Sentiment"] == "neutral"):
        neu9_repliedto = neu9_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "9" or row["Dominant_Topic"][1] == "9") and row["Sentiment"] == "positive"):
        pos9_repliedto = pos9_repliedto.append(row)
    if((row["Dominant_Topic"][0] == "9" or row["Dominant_Topic"][1] == "9") and row["Sentiment"] == "negative"):
        neg9_repliedto = neg9_repliedto.append(row)

pos0_repliedto.to_pickle("topic_sentiment_dfs/pos0_phase3")
neu0_repliedto.to_pickle("topic_sentiment_dfs/neu0_phase3")
neg0_repliedto.to_pickle("topic_sentiment_dfs/neg0_phase3")
pos1_repliedto.to_pickle("topic_sentiment_dfs/pos1_phase3")
neu1_repliedto.to_pickle("topic_sentiment_dfs/neu1_phase3")
neg1_repliedto.to_pickle("topic_sentiment_dfs/neg1_phase3")
pos2_repliedto.to_pickle("topic_sentiment_dfs/pos2_phase3")
neu2_repliedto.to_pickle("topic_sentiment_dfs/neu2_phase3")
neg2_repliedto.to_pickle("topic_sentiment_dfs/neg2_phase3")
pos3_repliedto.to_pickle("topic_sentiment_dfs/pos3_phase3")
neu3_repliedto.to_pickle("topic_sentiment_dfs/neu3_phase3")
neg3_repliedto.to_pickle("topic_sentiment_dfs/neg3_phase3")
pos4_repliedto.to_pickle("topic_sentiment_dfs/pos4_phase3")
neu4_repliedto.to_pickle("topic_sentiment_dfs/neu4_phase3")
neg4_repliedto.to_pickle("topic_sentiment_dfs/neg4_phase3")
pos5_repliedto.to_pickle("topic_sentiment_dfs/pos5_phase3")
neu5_repliedto.to_pickle("topic_sentiment_dfs/neu5_phase3")
neg5_repliedto.to_pickle("topic_sentiment_dfs/neg5_phase3")
pos6_repliedto.to_pickle("topic_sentiment_dfs/pos6_phase3")
neu6_repliedto.to_pickle("topic_sentiment_dfs/neu6_phase3")
neg6_repliedto.to_pickle("topic_sentiment_dfs/neg6_phase3")
pos7_repliedto.to_pickle("topic_sentiment_dfs/pos7_phase3")
neu7_repliedto.to_pickle("topic_sentiment_dfs/neu7_phase3")
neg7_repliedto.to_pickle("topic_sentiment_dfs/neg7_phase3")
pos8_repliedto.to_pickle("topic_sentiment_dfs/pos8_phase3")
neu8_repliedto.to_pickle("topic_sentiment_dfs/neu8_phase3")
neg8_repliedto.to_pickle("topic_sentiment_dfs/neg8_phase3")
pos9_repliedto.to_pickle("topic_sentiment_dfs/pos9_phase3")
neu9_repliedto.to_pickle("topic_sentiment_dfs/neu9_phase3")
neg9_repliedto.to_pickle("topic_sentiment_dfs/neg9_phase3")
